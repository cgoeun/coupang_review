# %%
import pandas as pd
import pandas_profiling

data = pd.read_csv('C:/Users/admin/Desktop/1/coupang_review/reviews.csv')

# %%
list(data.iloc[1])[3]
# Out:
# 'QHD 240hz 완벽지원하는 제품이에요 저는 전자제품에 관심이 많아 모니터도 이리저리 많이도 바꾸고 설치환경에 변화도 잦은데, DP케이블과 HDMI케이블 제돈주고 산것만 못해도 50만원에서 200은 쓴거같아요 과장아니라 제 일도 이쪽이랑 관련이 있었어서 그렇다보니 케이블의 버전에 맞은 최대주사율과 해상도가 나뉨에 QHD환경에 240hz모니터에서도 완벽하게 대역폭을 소화해내는걸 확인할 수 있었습니다  1.4케이블 길이별로 다 써보고 그래도 마감상태부터 소재까지 제일 마음에 듭니다 DP케이블은 보통 커넥트부분에 스위치가 있는 경우가 많은데 플라스틱으로 된 제품들은 유독 갑작스러운 충격? 꺾임이 있게되면 부러지거나 깨져버려서 안에 피복이 노출되게 되는데 얘는 그렇진 않을꺼같아보입니다  케이블 선도 막무가네로 두껍다고 좋은게 아니라 어느정도 휠때 꺾이는 각도가 제법있어야 모니터나 대형 스크린에서 벽면에 밀착하기 편합니다 그래서 요 제품 비싸다고만 생각하지말고 구매 고려해봐도 좋을꺼같아보입니다'

# %%
pr = data.profile_report()
pr.to_file('./pr_report.html')
# Out:
# Summarize dataset:  50%|█████     | 8/16 [00:56<01:48, 13.59s/it, Calculate kendall correlation] c:\Users\admin\anaconda3\envs\web\lib\site-packages\scipy\stats\stats.py:4812: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# Summarize dataset: 100%|██████████| 19/19 [01:01<00:00,  3.22s/it, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:02<00:00,  2.36s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.73it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 283.69it/s]

# %%
import re

def find_not_text(text):
    pattern = '[\w\s]'         # 특수기호제거
    not_text = re.sub(pattern=pattern, repl='', string=text)
    not_text = re.sub('[.,?\(\)\:\\\]', '', not_text)
    # not_text = re.sub('[-=+#/\:^$@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', repl='', string=text)
    return not_text   

# len(find_not_text(list(data.iloc[1])[3]))

# %%
for i in range(500):
    print(find_not_text(list(data.iloc[i])[3]))
# Out:
# ♡♥!♥!♥*****************************""""*****************************♥~!!
#
#
#
#
#
#
# ~!~
# :~><
# ~
#
#
#
#
#
#
# ~"~"
#
#
# !
#
# ^^
#
# !!!!!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ~~
#
#
#
#
#
#
#
#
#
#
#
#
#
# !
#
#
#
#
# !
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# !!!!
#
# !
#
# ^^
#
#
#
#
# !
#
#
# ~
#
#
#
#
#
#
#
# ^^
#
#
#
#
#
#
# !!
# ~
#
#
#
#
#
#
#
#
#
#
#
#
# ~~
#
#
#
# :::
# ^^
#
# -!
#
# ^^!
# ^^
# ^^+
# ~!!~^^~!!~!~!!~!
#
# ♥️♥️
# ~~~^^
# !!♡♡♡!!!!!!!
# :->:->->:~%
# !~~~
#
# ;;
# ~~
#
# !
# !!!
# -/
#
# !-!-!!
# /
# !
#
# !~^^
# :!
# ;~
#
#
#
# ~
# !!!--!!!~~
#
# !!:
#
#
#
#
#
#
#
#
#
# ~!!
# !!!
# ^^
# ~~
# !!!!!!
#
#
# !!!!!
#
#
# ~
# !
#
#
#
# ;;;;!
# !
#
#
#
# ;;;;!
#
#
#
# ~
#
#
# !!^^-~~^^
# :
# ^^
# ><
# !
# !!!!
# !!
#
# !
#
#
#
#
#
#
# ~~~
#
# !
#
# ~~~
#
#
#
#
# ~
#
# !
# !!!!
# ~
#
#
#
#
# !
#
#
#
#
#
# ♥
#
#
#
#
# ♥
#
#
#
#
#
#
#
#
#
#
#
#
#
# !!
#
#
#
#
# ~~
#
#
# ^^
#
#
#
#
#
# !!~~
#
#
#
#
#
#
#
#
#
#
# ~^^~^^
#
#
#
#
#
#
#
#
#
# !
#
# ~^^
#
# ^^
#
#
# ~^^
#
# ^^
#
#
#
#
#
#
#
# !
#
#
#
#
#
#
#
#
#
# ~~
#
#
#
#
#
#
# ~^^
#
#
#
#
#
#
#
#
#
# :
# !
# ~~~~~~
#
#
#
#
#
#
#
#
# ~
#
# /^^
#
#
#
#
# /^^
#
#
#
#
#
#
#
#
#
#
#
#
# !!
#
#
#
#
# !!!!
#
# !
#
#
#
# ~!
#
#
#
#
#
#
# ~
#
# !
#
#
#
#
# !!
# !!^^
#
# ^^^^^^
#
# !!!!!!!!!
# !!!!!!~
# *
# --
#
#
#
# ~!!!
# ~~
# !
#
#
# ~!!!
# ~~
# !
#
# !
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ~
#
#
#
#
# ~
# !!!
# ~!
# !
#
# ~^^~^^~^^~^^~^^~^^~^^
# !~:
#
#
# !!!!!!!!++…++…<><>
#
#
# !-/////+;;;!''!!!!+/++''!!!
#
#
#
# !!!!!!
#
# ^^
# +
# !!
# -;;
# !!!
# --------->
# //
# !::
#
# /
# ;;
# !~~!
#
#
# --
#
# /
#
# /
# ~~~~~~~~~~~~~~~~~!!
#
#
#
#
#
#
# !
#
# -
#
# !
#
#
#
#
#
#
#
#
# !!!::
